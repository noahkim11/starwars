# %%
#filename = 'star wars - new hope.txt'
#location_marker = ['EXT.','INT.']

def parse_script(filename,location_marker):

    f = open(filename,'r')
    change_actor = False
    cur_location = ''
    location_counter = 0
    location = ''
    actor = ''
    lines = ''
    output = []
    
    for row in f:
        #blank line resets location and character change        
        if row == '\n' and change_actor:
            output.append([location, location_counter, actor, lines])
#            print(location, actor, lines)
            change_actor = False
            lines = ''
            continue

        #locations and characters flag
        if row == row.upper() and row != '\n':
            if any([True if x in row else False for x in location_marker]): #if EXT. or INT.        
                location = row.strip('\n')                
            else:
                change_actor = True            
                actor = row.strip('\n')
                lines = ''
            continue
        
        #multiple lines of dialog
        if change_actor:
            lines += row.strip('\n')            

        if not cur_location:
            cur_location = location
            
        if cur_location != location:
#            print(cur_location, location, location_counter)
            
            location_counter += 1
            cur_location = location
            
            
            
#            print(cur_location)
            
        
    f.close()
    return output

# %%
import pandas as pd

filename = 'star wars - new hope.txt'
location_marker = ['EXT.','INT.']

script = parse_script(filename,location_marker)

df = pd.DataFrame(script, columns=['location', 'location_counter', 'actor', 'lines'])
df = df[df['location']!='']

#for item in script:
#    print(item)

#df.to_csv('output.csv', index=False)

# %%
import nltk, re, pprint
from nltk import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
output = []

#for item in df['lines'].values:
for item in zip(df.values):
    line = item[0][3]

    #score the lines
    ss = sid.polarity_scores(line)
    
#    output.append([item[0][0], item[0][1], item[0][2], ss['neg'], ss['neu'], ss['pos'], ss['compound']])
    output.append(list(item[0]) + [ss['neg'], ss['neu'], ss['pos'], ss['compound']])
          
#    for k in sorted(ss):
#        print('{0}: {1}, '.format(k, ss[k]),end='')

#    tokens = word_tokenize(item)
#    test = nltk.sentiment.vader.SentiText(item)
#    print(nltk.sentiment.vader.SentimentIntensityAnalyzer(test))
#    print(tokens)

df1 = pd.DataFrame(output, columns = ['location','location_counter', 'actor','line', 'neg','neu','pos','compound'])

df1.to_csv('sw_newhope.csv')
# Out:
# C:\Users\Noah\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#from nltk.classify import NaiveBayesClassifier
#from nltk.corpus import subjectivity
#from nltk.sentiment import SentimentAnalyzer
#from nltk.sentiment.util import *

#for item in output:
#    print(item)


df1[df1['neg']>0.5]
# Out:
#                                                location  location_counter  \
# 1          INT. REBEL BLOCKADE RUNNER - MAIN PASSAGEWAY                 0
# 99                                     INT. SANDCRAWLER                25
# 175   INT. LARS HOMESTEAD - GARAGE AREA - LATE AFTER...                27
# 201                        INT. LARS HOMESTEAD - GARAGE                30
# 255                              INT. KENOBI'S DWELLING                42
# 335                INT. TATOOINE - MOS EISLEY - CANTINA                51
# 339                INT. TATOOINE - MOS EISLEY - CANTINA                51
# 341                INT. TATOOINE - MOS EISLEY - CANTINA                51
# 375                           INT. MOS EISLEY - CANTINA                55
# 378                           INT. MOS EISLEY - CANTINA                55
# 411         INT. MOS EISLEY SPACEPORT - DOCKING BAY 94]                66
# 441                      INT. DEATH STAR - CONTROL ROOM                78
# 452          INT. MILLENNIUM FALCON - CENTRAL HOLD AREA                80
# 476                   INT. DEATH STAR - CONFERENCE ROOM                81
# 597                                 INT. DETENTION AREA               103
# 638   INT. DEATH STAR - MAIN BAY GANTRY - CONTROL TOWER               107
# 649                      INT. DEATH STAR - GARBAGE ROOM               109
# 654                      INT. DEATH STAR - GARBAGE ROOM               109
# 731                INT. DEATH STAR - CENTRAL CORE SHAFT               128
# 744   INT. DEATH STAR - HALLWAY LEADING TO MAIN FORW...               132
# 755                           INT. DEATH STAR - HALLWAY               136
# 798                    INT. MILLENNIUM FALCON - COCKPIT               183
# 822                 INT. MAIN HANGAR DECK - LUKE'S SHIP               196
# 863                    INT. MASSASSI OUTPOST - WAR ROOM               223
# 901                          INT. DARTH VADER'S COCKPIT               283
# 965                INT. LUKE'S X-WING FIGHTER - COCKPIT               382
# 970                                INT. WEDGE'S COCKPIT               393
# 985                          EXT. LUKE'S X-WING FIGHTER               436
# 1005                INT. MASSASSI OUTPOST - MAIN HANGAR               468
#
#           actor                                               line    neg  \
# 1      THREEPIO                                      We're doomed!  0.818
# 99     THREEPIO                                      We're doomed.  0.808
# 175    THREEPIO                       No, I don't like you either.  0.590
# 201        LUKE                                            Oh, no!  0.714
# 255        LUKE                      You fought in the Clone Wars?  0.596
# 335        LUKE                                         I'm sorry.  0.565
# 339       HUMAN                                    You'll be dead.  0.683
# 341   BARTENDER                           No blasters! No blaster!  0.714
# 375         HAN                                 Over my dead body.  0.589
# 378         HAN                              Sorry about the mess.  0.655
# 411     TROOPER                                    Stop that ship!  0.555
# 441        LEIA                                                No!  1.000
# 452    THREEPIO   But sir, nobody worries about upsetting a droid.  0.541
# 476      TARKIN                          She lied! She lied to us!  0.591
# 597        LUKE  Prisoner transfer from Block one-one-three-eight.  0.681
# 638    THREEPIO                                            Oh, no!  0.714
# 649        LUKE                                          No! wait!  0.736
# 654         HAN                                        It's worse.  0.756
# 731        LEIA                                   There's no lock!  0.555
# 744         BEN                      Only a master of evil, Darth.  0.524
# 755        LUKE                                                No!  1.000
# 798        LUKE                                                No!  1.000
# 822        LEIA                                      What's wrong?  0.756
# 863       WEDGE  (over war room speaker system)Heavy fire, boss...  0.524
# 901       VADER                          Stay in attack formation!  0.531
# 965        LUKE  You worry about those fighters! I'll worry abo...  0.520
# 970       WEDGE                                             Sorry!  1.000
# 985        LUKE                                   I've lost Artoo!  0.564
# 1005       LUKE                                            Oh, no!  0.714
#
#         neu  pos  compound
# 1     0.182  0.0   -0.6696
# 99    0.192  0.0   -0.6369
# 175   0.410  0.0   -0.5122
# 201   0.286  0.0   -0.3595
# 255   0.404  0.0   -0.7096
# 335   0.435  0.0   -0.0772
# 339   0.317  0.0   -0.6486
# 341   0.286  0.0   -0.6103
# 375   0.411  0.0   -0.6486
# 378   0.345  0.0   -0.4215
# 411   0.445  0.0   -0.3595
# 441   0.000  0.0   -0.3595
# 452   0.459  0.0   -0.7096
# 476   0.409  0.0   -0.6988
# 597   0.319  0.0   -0.7506
# 638   0.286  0.0   -0.3595
# 649   0.264  0.0   -0.4184
# 654   0.244  0.0   -0.4767
# 731   0.445  0.0   -0.3595
# 744   0.476  0.0   -0.6597
# 755   0.000  0.0   -0.3595
# 798   0.000  0.0   -0.3595
# 822   0.244  0.0   -0.4767
# 863   0.476  0.0   -0.7644
# 901   0.469  0.0   -0.5255
# 965   0.480  0.0   -0.7639
# 970   0.000  0.0   -0.1511
# 985   0.436  0.0   -0.3802
# 1005  0.286  0.0   -0.3595

# %%
import networkx as nx
import matplotlib.pyplot as plt

G.add_node("spam")
G.add_edge(1,2)
#print(list(G.nodes()))
#[1, 2, 'spam']
#print(list(G.edges()))
#[(1, 2)]


nx.draw(G)
plt.show()
